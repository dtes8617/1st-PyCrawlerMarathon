# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 下載檔案

# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
# r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

response
# Out:
# '[{"id":232657695,"title":"不是貓的貓","excerpt":"企鵝4ni！？ （尾巴還剛好一搓，J個難道是狐獴？泥4天使！？哥吉拉都出來了🤣，暖暖包️，搜～得斯，咘咘：欠打是嗎？：...有人可以幫我打113嗎？補個手嚕貓（？","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-12-10T02:41:33.923Z","updatedAt":"2019-12-11T02:36:25.033Z","commentCount":23,"likeCount":717,"withNickname":false,"tags":[],"topics":["貓","寵物"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"M","school":"嘉南藥理大學","replyTitle":null,"mediaMeta":[{"id":"12b36ab6-a078-481d-822a-84bc13ac5ae4","url":"https://i.imgur.com/UYBdD5Wl.jpg","normalizedUrl":"https://i.imgur.com/UYBdD5Wl.jpg","thumbnail":"https://i.imgur.com/UYBdD5Wl.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-12-10T02:41:33.923Z","updatedAt":"2019-12-11T02:36:25.033Z"},{"id":"12b36ab6-a078-481d-822a-84bc13ac5ae4","url":"https://i.imgur.com/UYBdD5W.jpg","normalizedUrl":"https://imgur.com/UYBdD5W","thumbnail":"https://i.imgur.com/UYBdD5Wl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-10T02:41:33.923Z","updatedAt":"2019-12-11T02:36:25.033Z"},{"id":"878fe61d-84c8-4402-b33d-5188db81bcd9","url":"https://i.imgur.com/jf5xCad.jpg","normalizedUrl":"https://imgur.com/jf5xCad","thumbnail":"https://i.imgur.com/jf5xCadl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-10T02:41:33.923Z","updatedAt":"2019-12-11T02:36:25.033Z"},{"id":"0affd655-c303-42a2-800e-96debf27e26b","url":"https://i.imgur.com/5Z7LFe6.jpg","normalizedUrl":"https://imgur.com/5Z7LFe6","thumbnail":"https://i.imgur.com/5Z7LFe6l.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-10T02:41:33.923Z","updatedAt":"2019-12-11T02:36:25.033Z"},{"id":"2db47782-e304-4b9a-b18b-419014e39c37","url":"https://i.imgur.com/C0uuLAs.jpg","normalizedUrl":"https://imgur.com/C0uuLAs","thumbnail":"https://i.imgur.com/C0uuLAsl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-10T02:41:33.923Z","updatedAt":"2019-12-11T02:36:25.033Z"},{"id":"b530cb8b-60d3-4fd6-95ab-7668111d6fe1","url":"https://i.imgur.com/sT98E8Y.jpg","normalizedUrl":"https://imgur.com/sT98E8Y","thumbnail":"https://i.imgur.com/sT98E8Yl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-10T02:41:33.923Z","updatedAt":"2019-12-11T02:36:25.033Z"},{"id":"c9ea7e1c-7da2-46d5-b44e-2919443ac9ff","url":"https://i.imgur.com/maS7Ux6.jpg","normalizedUrl":"https://imgur.com/maS7Ux6","thumbnail":"https://i.imgur.com/maS7Ux6l.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-10T02:41:33.923Z","updatedAt":"2019-12-11T02:36:25.033Z"},{"id":"0383fc24-90cf-43c3-bf81-afa5b73154fa","url":"https://i.imgur.com/s0dbpRE.jpg","normalizedUrl":"https://imgur.com/s0dbpRE","thumbnail":"https://i.imgur.com/s0dbpREl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-10T02:41:33.923Z","updatedAt":"2019-12-11T02:36:25.033Z"},{"id":"101e9665-4197-4280-ac89-f940945b0c32","url":"https://www.dcard.tw/v2/vivid/videos/a78bee76-06a8-498a-b9bf-fd6e094f3171?r=1.7777777777777777","normalizedUrl":"","thumbnail":"https://vivid.dcard.tw/Public/a78bee76-06a8-498a-b9bf-fd6e094f3171/thumbnail.jpg","type":"video/vivid","tags":["ANNOTATED_FAILED"],"createdAt":"2019-12-11T02:36:25.033Z","updatedAt":"2019-12-11T02:36:25.033Z"}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":704},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":13}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":true,"media":[{"url":"https://i.imgur.com/UYBdD5W.jpg"},{"url":"https://i.imgur.com/jf5xCad.jpg"},{"url":"https://i.imgur.com/5Z7LFe6.jpg"},{"url":"https://i.imgur.com/C0uuLAs.jpg"},{"url":"https://i.imgur.com/sT98E8Y.jpg"},{"url":"https://i.imgur.com/maS7Ux6.jpg"},{"url":"https://i.imgur.com/s0dbpRE.jpg"},{"url":"https://vivid.dcard.tw/Public/a78bee76-06a8-498a-b9bf-fd6e094f3171/thumbnail.jpg"}],"reportReasonText":"","postAvatar ...

# %%
import json
data = json.loads(response)

for d in data:
    print(d['title'])
# Out:
# 貓咪道歉
# 阿嬤你在這啊
# #求領養 帶她回家巴
# 🐶讓毛孩健健康康過聖誕🐱純肉食堂每餐都舔光光😋
# 溫暖，但我快不能呼吸
# 不是貓的貓
# 原來是跳水選手啊？我還以為是貓呢！
# 這是我寶貝不准搶喔
# 把鼠鼠交出來！
# 線上等 急 被黏住了該怎麼辦
# #心情 第一次感受到養寵物的重量可以有多沈重
# 穿越半個台北的緣份，她的一句話，一個承諾，我會陪妳到最後。（圖多文長
# 92歲 vs 3歲
# #圖多  沙發馬鈴🐭報到！✨
# 大家的白文鳥想睡覺會不會變棉花糖
# 貓咪能多長
# 傻呼呼的小兔(*´∀`)~♥
# 每次都懷疑貓咪的身體裡面裝人的靈魂⋯
# 寵物展之自己的飼料自己賺🐰
# 喜歡吹風機的鳥鳥
# 貓咪走失...
# 嗨 你們長大了！
# 愛他就盡量減少傷害他的可能性！
# 狗狗的粉刺
# 學生中途，學生領養
# 簡單問卷求協助！再放一些可愛的倉鼠照<3
# 蛋蛋脫皮脫到一半大便了
# 蠻好奇我家兔兔的品種😆因為這隻是之前在外頭流浪,被我收編的—————————————放上美照⬇️
# 養寵物前你準備好了嗎？
# #貓 #圖 先森你的頭忘在外面了喔

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
#     1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
#     2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
#     3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
