# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# [問卦] 3片/7天...484可以戴好戴滿惹?
#
#
# Radiomir
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Radiomir 的文章
#
#
#  3/02
#
#
#
#
# 3
#
# [問卦] 台灣檢驗情況如何
#
#
# zzing
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zzing 的文章
#
#
#  3/02
#
#
#
#
# 25
#
# [問卦] 如果瑞典環保少女奶很大怎麼辦?
#
#
# GOD5566GOD
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 GOD5566GOD 的文章
#
#
#  3/02
#
#
#
#
#
#
# [新聞] 舔中女星宣布參與中國器捐 被讚「中國的
#
#
# zombie5623
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zombie5623 的文章
#
#
#  3/02
#
#
#
#
#
#
# Re: [新聞] 新北6警騙拘票衝績效 法官痛批：敗壞國家
#
#
# winogu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 winogu 的文章
#
#
#  3/02
#
#
#
#
# 1
#
# Re: [新聞] 中國人「依親探親」可享健保? 陳柏惟籲廢
#
#
# leavez
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leavez 的文章
#
#
#  3/02
#
#
#
#
# 2
#
# Re: [問卦] 鳥山明的七龍珠超，為何不採納別人
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  3/02
#
#
#
#
# 4
#
# [問卦] 日本人的效率很差唷?
#
#
# tagso
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 tagso 的文章
#
#
#  3/02
#
#
#
#
#
#
# [問卦] 動！！！！敝校素質…
#
#
# jensheng09
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jensheng09 的文章
#
#
#  3/02
#
#
#
#
# 12
#
# [新聞] 護理師兒被要求在家隔離 工會怒聲明
#
#
# icedog122
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 icedog122 的文章
#
#
#  3/02
#
#
#
#
# 2
#
# [問卦] 米奇妙妙屋一次黏到6隻米奇該怎處理
#
#
# gn01948540
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 gn01948540 的文章
#
#
#  3/02
#
#
#
#
#
#
# [問卦] 如果沒發生疫情，會有什麼變化嗎?
#
#
# dingwk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dingwk 的文章
#
#
#  3/02
#
#
#
#
# X1
#
# [新聞] 砲轟口罩問題！李來希酸：偉大的民進黨政
#
#
# OmegaWind
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 OmegaWind 的文章
#
#
#  3/02
#
#
#
#
# 21
#
# [問卦] 三國第一猛將是誰？
#
#
# paulabxz123
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 paulabxz123 的文章
#
#
#  3/02
#
#
#
#
#
#
# [問卦] 邵o平現在不知道過得怎樣
#
#
# atticsalt
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 atticsalt 的文章
#
#
#  3/02
#
#
#
#
#
#
# Re: [爆卦] 中央研究院性醜聞！台法雙博士複雜關係！
#
#
# ffreakk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ffreakk 的文章
#
#
#  3/02
#
#
#
#
# 7
#
# [問卦] 男生說自己「比較大刺刺」的意思是？
#
#
# QnxQn
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 QnxQn 的文章
#
#
#  3/02
#
#
#
#
#
#
# Re: [問卦] 為什麼教育是教你做人要善良 誠實 正直
#
#
# imlitq
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 imlitq 的文章
#
#
#  3/02
#
#
#
#
# 4
#
# Re: [新聞] 柯文哲嗆陳時中公開隔離地 北市卻保密「
#
#
# yataiml001
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 yataiml001 的文章
#
#
#  3/02
#
#
#
#
# 3
#
# [新聞] 湘瑩夢碎!想生子找嘸人認識異性只想榨精
#
#
# ova132132
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ova132132 的文章
#
#
#  3/02
#
#
#
#
#
# 7
#
# [公告] 武漢肺炎討論專區&二月份置底閒聊文
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  2/03
# M
#
#
#
# 31
#
# [徵求] 行車記錄器 西濱100.4K苗栗後龍南下路段
#
#
# leel20
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leel20 的文章
#
#
#  2/25
# M
#
#
#
#
#
# [公告] 八卦板板規(2019.08.21)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  8/21
# !
#
#
#
# 4
#
# [徵求] 109/2/27行車紀錄器 南港環東大道
#
#
# ciphercindy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ciphercindy 的文章
#
#
#  3/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# [問卦] 3片/7天...484可以戴好戴滿惹?
#
#
# Radiomir
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Radiomir 的文章
#
#
#  3/02
#
#
#
#
# 3
#
# [問卦] 台灣檢驗情況如何
#
#
# zzing
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zzing 的文章
#
#
#  3/02
#
#
#
#
# 25
#
# [問卦] 如果瑞典環保少女奶很大怎麼辦?
#
#
# GOD5566GOD
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 GOD5566GOD 的文章
#
#
#  3/02
#
#
#
#
#
#
# [新聞] 舔中女星宣布參與中國器捐 被讚「中國的
#
#
# zombie5623
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zombie5623 的文章
#
#
#  3/02
#
#
#
#
#
#
# Re: [新聞] 新北6警騙拘票衝績效 法官痛批：敗壞國家
#
#
# winogu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 winogu 的文章
#
#
#  3/02
#
#
#
#
# 1
#
# Re: [新聞] 中國人「依親探親」可享健保? 陳柏惟籲廢
#
#
# leavez
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leavez 的文章
#
#
#  3/02
#
#
#
#
# 2
#
# Re: [問卦] 鳥山明的七龍珠超，為何不採納別人
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  3/02
#
#
#
#
# 4
#
# [問卦] 日本人的效率很差唷?
#
#
# tagso
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 tagso 的文章
#
#
#  3/02
#
#
#
#
#
#
# [問卦] 動！！！！敝校素質…
#
#
# jensheng09
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jensheng09 的文章
#
#
#  3/02
#
#
#
#
# 12
#
# [新聞] 護理師兒被要求在家隔離 工會怒聲明
#
#
# icedog122
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 icedog122 的文章
#
#
#  3/02
#
#
#
#
# 2
#
# [問卦] 米奇妙妙屋一次黏到6隻米奇該怎處理
#
#
# gn01948540
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 gn01948540 的文章
#
#
#  3/02
#
#
#
#
#
#
# [問卦] 如果沒發生疫情，會有什麼變化嗎?
#
#
# dingwk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dingwk 的文章
#
#
#  3/02
#
#
#
#
# X1
#
# [新聞] 砲轟口罩問題！李來希酸：偉大的民進黨政
#
#
# OmegaWind
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 OmegaWind 的文章
#
#
#  3/02
#
#
#
#
# 21
#
# [問卦] 三國第一猛將是誰？
#
#
# paulabxz123
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 paulabxz123 的文章
#
#
#  3/02
#
#
#
#
#
#
#
# 				(本文已被刪除) [atticsalt]
#
#
#
# -
#
#
#  3/02
#
#
#
#
#
#
# Re: [爆卦] 中央研究院性醜聞！台法雙博士複雜關係！
#
#
# ffreakk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ffreakk 的文章
#
#
#  3/02
#
#
#
#
# 7
#
# [問卦] 男生說自己「比較大刺刺」的意思是？
#
#
# QnxQn
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 QnxQn 的文章
#
#
#  3/02
#
#
#
#
#
#
# Re: [問卦] 為什麼教育是教你做人要善良 誠實 正直
#
#
# imlitq
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 imlitq 的文章
#
#
#  3/02
#
#
#
#
# 5
#
# Re: [新聞] 柯文哲嗆陳時中公開隔離地 北市卻保密「
#
#
# yataiml001
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 yataiml001 的文章
#
#
#  3/02
#
#
#
#
# 3
#
# [新聞] 湘瑩夢碎!想生子找嘸人認識異性只想榨精
#
#
# ova132132
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ova132132 的文章
#
#
#  3/02
#
#
#
#
#
# 7
#
# [公告] 武漢肺炎討論專區&二月份置底閒聊文
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  2/03
# M
#
#
#
# 31
#
# [徵求] 行車記錄器 西濱100.4K苗栗後龍南下路段
#
#
# leel20
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leel20 的文章
#
#
#  2/25
# M
#
#
#
#
#
# [公告] 八卦板板規(2019.08.21)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  8/21
# !
#
#
#
# 4
#
# [徵求] 109/2/27行車紀錄器 南港環東大道
#
#
# ciphercindy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ciphercindy 的文章
#
#
#  3/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）
