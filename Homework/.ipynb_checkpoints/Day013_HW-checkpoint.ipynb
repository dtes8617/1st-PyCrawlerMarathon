# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

resp = requests.get('https://www.ptt.cc/bbs/NBA/index.html')
soup = BeautifulSoup(resp.text).find('div', class_="r-list-container action-bar-margin bbs-screen")

soup_articles = soup.find_all('div', class_="r-ent")

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
import pandas as pd

articles = pd.DataFrame(columns=['date', 'author', 'title'])

for a in soup_articles:
    d = {}
    d['date'] = a.find('div', class_="date").text
    d['author'] = a.find('div', class_="author").text
    d['title'] = a.find('div', class_="title").a.text
    articles = articles.append(d, ignore_index=True)
articles
# Out:
#      date        author                                   title
# 0   12/15       blue999             [花邊]林書豪被看破手腳?中媒:CBA生存比NBA更難
# 1   12/15        kuluma                   [情報] WOJ：Doncic腳踝中度扭傷
# 2   12/15        wowoin                             [討論] 077這個傷
# 3   12/15      go190214              [新聞] 厄齊爾控中國迫害維吾爾 兵工廠仿NBA火箭
# 4   12/15    thnlkj0665            [花邊] 告別CBA返美訓練 史陶德邁爾仍有意再戰NBA
# 5   12/15       dog9527                     [討論] 喬丹快閃為啥台灣人還這麼愛他
# 6   12/15       MrSatan         Re: [情報] LeBron James進入30歲後數據表現
# 7   12/15     s27052705                        [討論] 林書豪算亞裔第一控嗎？
# 8   12/15       GodEyes           Re: [情報] De'Aaron Fox左腳踝第三級扭傷
# 9   12/15       dwyanes           Re: [新聞] 熱火昨輸球好冤 裁判3度漏吹都對湖人有利
# 10  12/15     bbbyes123               [新聞] 球員清晨5點才下榻飯店 瑞佛斯砲轟賽程安
# 11  12/15         Rambo                 [情報] ★今日排名(2019.12.15)★
# 12  12/15    a78998042a    [情報] NBA Standings (Dec. 15, 2019)
# 13  12/15   Ayanami5566                    [討論] 目前誰最有可能拿到最佳進步獎?
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

resp = requests.get('https://www.ptt.cc/bbs/creditcard/index.html')
soup = BeautifulSoup(resp.text).find('div', class_="r-list-container action-bar-margin bbs-screen")

soup_articles = soup.find_all('div', class_="r-ent")

import pandas as pd

articles = pd.DataFrame(columns=['date', 'author', 'title'])

for a in soup_articles:
    d = {}
    d['date'] = a.find('div', class_="date").text
    d['author'] = a.find('div', class_="author").text
    d['title'] = a.find('div', class_="title").a.text
    articles = articles.append(d, ignore_index=True)
articles
# Out:
#     date       author                                  title
# 0  12/15    dream2007                       [問題] 續卡沒收到後的處理方式
# 1  12/15    jimmy1010                            [問題] 關於帳單分期
# 2  12/15      tenghui                      [討論] 兆豐海外實體擋刷(越南)
# 3  12/15         swyn                  [問題] 帳單金額對個人信用或是聯徵的影響
# 4   2/28  MoonAthenaX  [公告] === 卡板板規 V8.0 === (2018/05/25修訂)
# 5   3/05     bboy0720                            [公告] 置底檢舉專區
# 6   3/09  MoonAthenaX                     [情報] 各家銀行0800免付費電話
# 7   6/13   DarkRobert           [整理] 小資族 日常消費優惠 回饋統整 (11/08)
# 8   7/02      cokelon              [心得] 2019下半年用卡整理 (12/4更新)
